# %% [markdown]
# ### Importando as bibliotecas

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Treinamento de Perceptron Multicamadas (MLP) para Problema XOR

# %%
def tanh(x):
     return np.tanh(x)

def derivative(x):
     return 1 - x**2

input = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

output = np.array([
    [0],
    [1],
    [1],
    [0]
])

np.random.seed(1)

w0 = 2 * np.random.random((2, 3)) - 1

w1 = 2 * np.random.random((3, 1)) - 1

epochs = 10000

learning_rate = 10

errors = []

# %% [markdown]
# ### Fase de Treinamento da Rede Neural Artificial

# %%
for i in range(epochs):

    # Forward
    hidden_input = np.dot(input, w0)
    hidden_layer = tanh(hidden_input)

    output_input = np.dot(hidden_layer, w1)
    output_layer = tanh(output_input)

    error = output - output_layer

    if i % 1000 == 0:
        print(f"Época {i} - Capturando erros: {np.mean(np.abs(error)):.4f}")
      
    delta_output = error * derivative(output_layer)

    error_hidden = delta_output.dot(w1.T)
    delta_hidden = error_hidden * derivative(hidden_layer)

    w1 += hidden_layer.T.dot(delta_output) * learning_rate
    w0 += input.T.dot(delta_hidden) * learning_rate

    errors.append(np.mean(np.abs(error)))  # salva o erro
# Out:
# Época 0 - Capturando erros: 0.4730
# Época 1000 - Capturando erros: 0.2500
# Época 2000 - Capturando erros: 0.2500
# Época 3000 - Capturando erros: 0.2500
# Época 4000 - Capturando erros: 0.2500
# Época 5000 - Capturando erros: 0.2500
# Época 6000 - Capturando erros: 0.2500
# Época 7000 - Capturando erros: 0.2500
# Época 8000 - Capturando erros: 0.2500
# Época 9000 - Capturando erros: 0.2500

# %% [markdown]
# ### Resultados

# %%
print("\nResultado binário:")
print((output_layer > 0.5).astype(int))

print("\nSaída esperada:")
print(output)

print("\nResultado final:")
print(output_layer)
# Out:
# Resultado binário:
# [[0]
#  [1]
#  [1]
#  [1]]
#
# Saída esperada:
# [[0]
#  [1]
#  [1]
#  [0]]
#
# Resultado final:
# [[0.        ]
#  [0.99999991]
#  [1.        ]
#  [1.        ]]

# %% [markdown]
# ## Plot sobre a rede neural

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(errors)
plt.title("Erro que ocorre")
plt.show()
